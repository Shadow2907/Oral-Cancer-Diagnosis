# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import VGG19

# %%
def load_data(folder_path):
    images = []
    labels = []
    for label, category in enumerate(['cancerous', 'non cancerous']):
        category_folder = os.path.join(folder_path, category)
        for file_name in os.listdir(category_folder):
            image_path = os.path.join(category_folder, file_name)
            image = load_img(image_path, target_size=(224, 224))
            image_array = img_to_array(image)
            images.append(image_array)
            labels.append(label)
    return np.array(images), np.array(labels)

# %%
folder_path = "/kaggle/input/oral-cancer-images/Oral_Cancer_Images"
images, labels = load_data(folder_path)
images = images / 255.0

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42, shuffle=True)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
)

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=32,
    shuffle=True
)

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-5)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)
model.save('VGG19.keras')
# Out:
# Epoch 1/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 91s 316ms/step - accuracy: 0.6473 - loss: 0.6187 - precision_1: 0.6389 - recall_1: 0.6308 - val_accuracy: 0.8033 - val_loss: 0.4567 - val_precision_1: 0.8592 - val_recall_1: 0.7181 - learning_rate: 1.0000e-04
# Epoch 2/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 51s 223ms/step - accuracy: 0.7981 - loss: 0.4528 - precision_1: 0.7978 - recall_1: 0.7830 - val_accuracy: 0.8377 - val_loss: 0.3840 - val_precision_1: 0.8487 - val_recall_1: 0.8158 - learning_rate: 1.0000e-04
# Epoch 3/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 218ms/step - accuracy: 0.8286 - loss: 0.3921 - precision_1: 0.8205 - recall_1: 0.8350 - val_accuracy: 0.8579 - val_loss: 0.3462 - val_precision_1: 0.8565 - val_recall_1: 0.8546 - learning_rate: 1.0000e-04
# Epoch 4/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 220ms/step - accuracy: 0.8441 - loss: 0.3590 - precision_1: 0.8422 - recall_1: 0.8383 - val_accuracy: 0.8617 - val_loss: 0.3297 - val_precision_1: 0.8980 - val_recall_1: 0.8113 - learning_rate: 1.0000e-04
# Epoch 5/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8571 - loss: 0.3379 - precision_1: 0.8497 - recall_1: 0.8556 - val_accuracy: 0.8738 - val_loss: 0.3081 - val_precision_1: 0.8564 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 6/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 218ms/step - accuracy: 0.8645 - loss: 0.3222 - precision_1: 0.8562 - recall_1: 0.8708 - val_accuracy: 0.8781 - val_loss: 0.2950 - val_precision_1: 0.8637 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 7/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8707 - loss: 0.3049 - precision_1: 0.8654 - recall_1: 0.8666 - val_accuracy: 0.8852 - val_loss: 0.2855 - val_precision_1: 0.8940 - val_recall_1: 0.8701 - learning_rate: 1.0000e-04
# Epoch 8/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8729 - loss: 0.2946 - precision_1: 0.8643 - recall_1: 0.8724 - val_accuracy: 0.8825 - val_loss: 0.2808 - val_precision_1: 0.8588 - val_recall_1: 0.9112 - learning_rate: 1.0000e-04
# Epoch 9/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8881 - loss: 0.2768 - precision_1: 0.8779 - recall_1: 0.8882 - val_accuracy: 0.8847 - val_loss: 0.2817 - val_precision_1: 0.9280 - val_recall_1: 0.8302 - learning_rate: 1.0000e-04
# Epoch 10/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8809 - loss: 0.2839 - precision_1: 0.8778 - recall_1: 0.8746 - val_accuracy: 0.8918 - val_loss: 0.2678 - val_precision_1: 0.9008 - val_recall_1: 0.8768 - learning_rate: 1.0000e-04
# Epoch 11/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8885 - loss: 0.2768 - precision_1: 0.8877 - recall_1: 0.8838 - val_accuracy: 0.8967 - val_loss: 0.2614 - val_precision_1: 0.9083 - val_recall_1: 0.8790 - learning_rate: 1.0000e-04
# Epoch 12/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8899 - loss: 0.2685 - precision_1: 0.8909 - recall_1: 0.8833 - val_accuracy: 0.8907 - val_loss: 0.2569 - val_precision_1: 0.8773 - val_recall_1: 0.9046 - learning_rate: 1.0000e-04
# Epoch 13/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8924 - loss: 0.2700 - precision_1: 0.8886 - recall_1: 0.8866 - val_accuracy: 0.8956 - val_loss: 0.2626 - val_precision_1: 0.9308 - val_recall_1: 0.8513 - learning_rate: 1.0000e-04
# Epoch 14/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8891 - loss: 0.2645 - precision_1: 0.8887 - recall_1: 0.8840 - val_accuracy: 0.8962 - val_loss: 0.2506 - val_precision_1: 0.8810 - val_recall_1: 0.9123 - learning_rate: 1.0000e-04
# Epoch 15/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.8938 - loss: 0.2551 - precision_1: 0.8890 - recall_1: 0.8917 - val_accuracy: 0.8891 - val_loss: 0.2542 - val_precision_1: 0.8554 - val_recall_1: 0.9323 - learning_rate: 1.0000e-04
# Epoch 16/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 220ms/step - accuracy: 0.8995 - loss: 0.2488 - precision_1: 0.8931 - recall_1: 0.9041 - val_accuracy: 0.9027 - val_loss: 0.2460 - val_precision_1: 0.9208 - val_recall_1: 0.8779 - learning_rate: 1.0000e-04
# Epoch 17/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9021 - loss: 0.2411 - precision_1: 0.8942 - recall_1: 0.9021 - val_accuracy: 0.8973 - val_loss: 0.2410 - val_precision_1: 0.8846 - val_recall_1: 0.9101 - learning_rate: 1.0000e-04
# Epoch 18/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 220ms/step - accuracy: 0.8962 - loss: 0.2411 - precision_1: 0.8922 - recall_1: 0.8997 - val_accuracy: 0.9038 - val_loss: 0.2379 - val_precision_1: 0.9068 - val_recall_1: 0.8968 - learning_rate: 1.0000e-04
# Epoch 19/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9069 - loss: 0.2291 - precision_1: 0.9022 - recall_1: 0.9047 - val_accuracy: 0.9038 - val_loss: 0.2392 - val_precision_1: 0.9240 - val_recall_1: 0.8768 - learning_rate: 1.0000e-04
# Epoch 20/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9075 - loss: 0.2325 - precision_1: 0.9037 - recall_1: 0.9059 - val_accuracy: 0.9055 - val_loss: 0.2348 - val_precision_1: 0.9146 - val_recall_1: 0.8912 - learning_rate: 1.0000e-04
# Epoch 21/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9075 - loss: 0.2335 - precision_1: 0.9048 - recall_1: 0.9045 - val_accuracy: 0.9049 - val_loss: 0.2354 - val_precision_1: 0.9251 - val_recall_1: 0.8779 - learning_rate: 1.0000e-04
# Epoch 22/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9082 - loss: 0.2334 - precision_1: 0.9087 - recall_1: 0.9033 - val_accuracy: 0.9049 - val_loss: 0.2285 - val_precision_1: 0.8964 - val_recall_1: 0.9123 - learning_rate: 1.0000e-04
# Epoch 23/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9119 - loss: 0.2247 - precision_1: 0.9039 - recall_1: 0.9140 - val_accuracy: 0.9033 - val_loss: 0.2354 - val_precision_1: 0.9330 - val_recall_1: 0.8657 - learning_rate: 1.0000e-04
# Epoch 24/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9092 - loss: 0.2228 - precision_1: 0.9092 - recall_1: 0.9028 - val_accuracy: 0.8962 - val_loss: 0.2380 - val_precision_1: 0.8559 - val_recall_1: 0.9489 - learning_rate: 1.0000e-04
# Epoch 25/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9064 - loss: 0.2245 - precision_1: 0.8968 - recall_1: 0.9138 - val_accuracy: 0.9093 - val_loss: 0.2223 - val_precision_1: 0.9134 - val_recall_1: 0.9012 - learning_rate: 1.0000e-04
# Epoch 26/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9038 - loss: 0.2147 - precision_1: 0.8975 - recall_1: 0.9023 - val_accuracy: 0.9087 - val_loss: 0.2220 - val_precision_1: 0.9189 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 27/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9091 - loss: 0.2215 - precision_1: 0.9069 - recall_1: 0.9039 - val_accuracy: 0.9115 - val_loss: 0.2223 - val_precision_1: 0.8943 - val_recall_1: 0.9301 - learning_rate: 1.0000e-04
# Epoch 28/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 220ms/step - accuracy: 0.9119 - loss: 0.2190 - precision_1: 0.9061 - recall_1: 0.9112 - val_accuracy: 0.9120 - val_loss: 0.2184 - val_precision_1: 0.9066 - val_recall_1: 0.9156 - learning_rate: 1.0000e-04
# Epoch 29/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9149 - loss: 0.2062 - precision_1: 0.9064 - recall_1: 0.9202 - val_accuracy: 0.9158 - val_loss: 0.2189 - val_precision_1: 0.8952 - val_recall_1: 0.9390 - learning_rate: 1.0000e-04
# Epoch 30/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 218ms/step - accuracy: 0.9132 - loss: 0.2127 - precision_1: 0.9029 - recall_1: 0.9216 - val_accuracy: 0.9153 - val_loss: 0.2164 - val_precision_1: 0.9002 - val_recall_1: 0.9312 - learning_rate: 1.0000e-04
# Epoch 31/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 218ms/step - accuracy: 0.9192 - loss: 0.1997 - precision_1: 0.9161 - recall_1: 0.9180 - val_accuracy: 0.9131 - val_loss: 0.2133 - val_precision_1: 0.9235 - val_recall_1: 0.8979 - learning_rate: 1.0000e-04
# Epoch 32/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9112 - loss: 0.2108 - precision_1: 0.9039 - recall_1: 0.9131 - val_accuracy: 0.9137 - val_loss: 0.2130 - val_precision_1: 0.9207 - val_recall_1: 0.9023 - learning_rate: 1.0000e-04
# Epoch 33/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 218ms/step - accuracy: 0.9113 - loss: 0.2077 - precision_1: 0.9066 - recall_1: 0.9109 - val_accuracy: 0.9126 - val_loss: 0.2153 - val_precision_1: 0.8855 - val_recall_1: 0.9445 - learning_rate: 1.0000e-04
# Epoch 34/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9160 - loss: 0.1988 - precision_1: 0.9117 - recall_1: 0.9128 - val_accuracy: 0.9191 - val_loss: 0.2081 - val_precision_1: 0.9197 - val_recall_1: 0.9156 - learning_rate: 1.0000e-04
# Epoch 35/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9164 - loss: 0.2023 - precision_1: 0.9138 - recall_1: 0.9131 - val_accuracy: 0.9137 - val_loss: 0.2118 - val_precision_1: 0.8866 - val_recall_1: 0.9456 - learning_rate: 1.0000e-04
# Epoch 36/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9185 - loss: 0.1950 - precision_1: 0.9159 - recall_1: 0.9181 - val_accuracy: 0.9219 - val_loss: 0.2053 - val_precision_1: 0.9202 - val_recall_1: 0.9212 - learning_rate: 1.0000e-04
# Epoch 37/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9211 - loss: 0.1941 - precision_1: 0.9193 - recall_1: 0.9169 - val_accuracy: 0.9115 - val_loss: 0.2184 - val_precision_1: 0.8767 - val_recall_1: 0.9545 - learning_rate: 1.0000e-04
# Epoch 38/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9252 - loss: 0.1867 - precision_1: 0.9205 - recall_1: 0.9263 - val_accuracy: 0.9153 - val_loss: 0.2099 - val_precision_1: 0.9378 - val_recall_1: 0.8868 - learning_rate: 1.0000e-04
# Epoch 39/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9180 - loss: 0.1938 - precision_1: 0.9136 - recall_1: 0.9177 - val_accuracy: 0.9230 - val_loss: 0.2030 - val_precision_1: 0.9104 - val_recall_1: 0.9356 - learning_rate: 1.0000e-04
# Epoch 40/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9272 - loss: 0.1846 - precision_1: 0.9247 - recall_1: 0.9263 - val_accuracy: 0.9164 - val_loss: 0.2058 - val_precision_1: 0.9379 - val_recall_1: 0.8890 - learning_rate: 1.0000e-04
# Epoch 41/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9289 - loss: 0.1801 - precision_1: 0.9288 - recall_1: 0.9234 - val_accuracy: 0.9251 - val_loss: 0.1985 - val_precision_1: 0.9331 - val_recall_1: 0.9134 - learning_rate: 1.0000e-04
# Epoch 42/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9273 - loss: 0.1776 - precision_1: 0.9206 - recall_1: 0.9334 - val_accuracy: 0.9093 - val_loss: 0.2144 - val_precision_1: 0.9543 - val_recall_1: 0.8568 - learning_rate: 1.0000e-04
# Epoch 43/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9238 - loss: 0.1870 - precision_1: 0.9217 - recall_1: 0.9218 - val_accuracy: 0.9186 - val_loss: 0.2012 - val_precision_1: 0.8941 - val_recall_1: 0.9467 - learning_rate: 1.0000e-04
# Epoch 44/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9278 - loss: 0.1836 - precision_1: 0.9259 - recall_1: 0.9238 - val_accuracy: 0.9180 - val_loss: 0.2009 - val_precision_1: 0.9412 - val_recall_1: 0.8890 - learning_rate: 1.0000e-04
# Epoch 45/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9224 - loss: 0.1794 - precision_1: 0.9154 - recall_1: 0.9255 - val_accuracy: 0.9219 - val_loss: 0.1958 - val_precision_1: 0.9015 - val_recall_1: 0.9445 - learning_rate: 1.0000e-04
# Epoch 46/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9323 - loss: 0.1758 - precision_1: 0.9264 - recall_1: 0.9342 - val_accuracy: 0.9262 - val_loss: 0.1920 - val_precision_1: 0.9333 - val_recall_1: 0.9156 - learning_rate: 1.0000e-04
# Epoch 47/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 220ms/step - accuracy: 0.9373 - loss: 0.1681 - precision_1: 0.9342 - recall_1: 0.9376 - val_accuracy: 0.9295 - val_loss: 0.1895 - val_precision_1: 0.9223 - val_recall_1: 0.9356 - learning_rate: 1.0000e-04
# Epoch 48/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9366 - loss: 0.1647 - precision_1: 0.9337 - recall_1: 0.9378 - val_accuracy: 0.9257 - val_loss: 0.1917 - val_precision_1: 0.9371 - val_recall_1: 0.9101 - learning_rate: 1.0000e-04
# Epoch 49/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9310 - loss: 0.1758 - precision_1: 0.9258 - recall_1: 0.9327 - val_accuracy: 0.9295 - val_loss: 0.1885 - val_precision_1: 0.9367 - val_recall_1: 0.9190 - learning_rate: 1.0000e-04
# Epoch 50/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step - accuracy: 0.9368 - loss: 0.1738 - precision_1: 0.9359 - recall_1: 0.9350 - val_accuracy: 0.9306 - val_loss: 0.1866 - val_precision_1: 0.9243 - val_recall_1: 0.9356 - learning_rate: 1.0000e-04

# %%
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Cancer", "Non-Cancer"], yticklabels=["Cancer", "Non-Cancer"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step
